# %% [markdown]
# ## dict.clear 清空字典元素

# %% [markdown]
# 字典方法 dict.clear()，Python 官方文档描述如下：

# %%
help(dict.clear)
# Out:
# Help on method_descriptor:
#
# clear(...)
#     D.clear() -> None.  Remove all items from D.

# %% [markdown]
# 清空字典元素。

# %%
d = {'a':1, 'b':2}
d.clear()
d
# Out:
# {}

# %% [markdown]
# 该方法是一个过程，返回值为 None。

# %%
d = {'a':1, 'b':2}
print(d.clear())
# Out:
# None
